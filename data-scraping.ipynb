# %%
import yfinance as yf

data = yf.download("^GSPC", start="2010-01-01", end="2025-09-29")
data.columns = data.columns.droplevel(1)
data.columns.name = None
data.reset_index(inplace=True)
data.tail()
